# %% [markdown]
# # Question 2 : Wrangling the Billboard Top 100

# %% [markdown]
# Consider the data in billboard.csv containing every song to appear on the weekly Billboard Top 100 chart since 1958, up through the middle of 2021. Each row of this data corresponds to a single song in a single week. For our purposes, the relevant columns here are:
#
# performer: who performed the song
#
# song: the title of the song
#
# year: year (1958 to 2021)
#
# week: chart week of that year (1, 2, etc)
#
# week_position: what position that song occupied that week on the Billboard top 100 chart.
#
# Use your skills in data wrangling and plotting to answer the following three questions.
#
# Part A: Make a table of the top 10 most popular songs since 1958, as measured by the total number of weeks that a song spent on the Billboard Top 100. Note that these data end in week 22 of 2021, so the most popular songs of 2021 will not have up-to-the-minute data; please send our apologies to The Weeknd.
#
# Your table should have 10 rows and 3 columns: performer, song, and count, where count represents the number of weeks that song appeared in the Billboard Top 100. Make sure the entries are sorted in descending order of the count variable, so that the more popular songs appear at the top of the table. Give your table a short caption describing what is shown in the table.
#
# (Note: you'll want to use both performer and song in any group_by operations, to account for the fact that multiple unique songs can share the same title.)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('billboard.csv')
df
# Out:
#         Unnamed: 0                                                url  \
# 0                1  http://www.billboard.com/charts/hot-100/1965-0...
# 1                2  http://www.billboard.com/charts/hot-100/1965-0...
# 2                3  http://www.billboard.com/charts/hot-100/1965-0...
# 3                4  http://www.billboard.com/charts/hot-100/1965-0...
# 4                5  http://www.billboard.com/charts/hot-100/1965-0...
# ...            ...                                                ...
# 327890      327891  https://www.billboard.com/charts/hot-100/2018-...
# 327891      327892  http://www.billboard.com/charts/hot-100/1977-0...
# 327892      327893  http://www.billboard.com/charts/hot-100/1981-0...
# 327893      327894  http://www.billboard.com/charts/hot-100/1973-0...
# 327894      327895  https://www.billboard.com/charts/hot-100/2020-...
#
#            week_id  week_position                      song  \
# 0        7/17/1965             34    Don't Just Stand There
# 1        7/24/1965             22    Don't Just Stand There
# 2        7/31/1965             14    Don't Just Stand There
# 3         8/7/1965             10    Don't Just Stand There
# 4        8/14/1965              8    Don't Just Stand There
# ...            ...            ...                       ...
# 327890  10/20/2018             22            God Is A Woman
# 327891   5/21/1977             22   I Wanna Get Next To You
# 327892   5/23/1981             22          I Can't Stand It
# 327893   9/29/1973             22  Here I Am Come & Take Me
# 327894  11/28/2020             22                     Hawai
#
#                         performer                                    song_id  \
# 0                      Patty Duke           Don't Just Stand TherePatty Duke
# 1                      Patty Duke           Don't Just Stand TherePatty Duke
# 2                      Patty Duke           Don't Just Stand TherePatty Duke
# 3                      Patty Duke           Don't Just Stand TherePatty Duke
# 4                      Patty Duke           Don't Just Stand TherePatty Duke
# ...                           ...                                        ...
# 327890              Ariana Grande                God Is A WomanAriana Grande
# 327891                 Rose Royce          I Wanna Get Next To YouRose Royce
# 327892  Eric Clapton And His Band  I Can't Stand ItEric Clapton And His Band
# 327893                   Al Green           Here I Am Come & Take MeAl Green
# 327894        Maluma & The Weeknd                   HawaiMaluma & The Weeknd
#
#         instance  previous_week_position  peak_position  weeks_on_chart  year  \
# 0              1                    45.0             34               4  1965
# 1              1                    34.0             22               5  1965
# 2              1                    22.0             14               6  1965
# 3              1                    14.0             10               7  1965
# 4              1                    10.0              8               8  1965
# ...          ...                     ...            ...             ...   ...
# 327890         1                    21.0              8              13  2018
# 327891         1                    10.0             10              13  1977
# 327892         1                    12.0             10              13  1981
# 327893         1                    16.0             10              13  1973
# 327894         1                    12.0             12              13  2020
#
#         week
# 0         29
# 1         30
# 2         31
# 3         32
# 4         33
# ...      ...
# 327890    42
# 327891    21
# 327892    21
# 327893    39
# 327894    48
#
# [327895 rows x 13 columns]

# %%
song_popularity = df.groupby(['performer','song']).count()[['week']].sort_values(by = 'week' ,ascending = False).reset_index()
song_popularity.rename(columns={'week': 'count'}, inplace=True)
print('Top 10 most popular songs since 1958')
song_popularity[:10]
# Out:
# Top 10 most popular songs since 1958
# P.S. Apologies to the Weeknd that we have data only till Week 22 of 2021
#                                    performer  \
# 0                            Imagine Dragons
# 1                                 AWOLNATION
# 2                                 The Weeknd
# 3                                 Jason Mraz
# 4                                LeAnn Rimes
# 5                                OneRepublic
# 6  LMFAO Featuring Lauren Bennett & GoonRock
# 7                                      Jewel
# 8                                      Adele
# 9                           Carrie Underwood
#
#                                   song  count
# 0                          Radioactive     87
# 1                                 Sail     79
# 2                      Blinding Lights     76
# 3                            I'm Yours     76
# 4                        How Do I Live     69
# 5                       Counting Stars     68
# 6                    Party Rock Anthem     68
# 7  Foolish Games/You Were Meant For Me     65
# 8                  Rolling In The Deep     65
# 9                     Before He Cheats     64

# %% [markdown]
# P.S. Apologies to the Weeknd that we have data only till Week 22 of 2021

# %% [markdown]
# Part B: Is the "musical diversity" of the Billboard Top 100 changing over time? Let's find out. We'll measure the musical diversity of given year as the number of unique songs that appeared in the Billboard Top 100 that year. Make a line graph that plots this measure of musical diversity over the years. The x axis should show the year, while the y axis should show the number of unique songs appearing at any position on the Billboard Top 100 chart in any week that year. For this part, please filter the data set so that it excludes the years 1958 and 2021, since we do not have complete data on either of those years. Give the figure an informative caption in which you explain what is shown in the figure and comment on any interesting trends you see.
#
# There are number of ways to accomplish the data wrangling here. For example, you could use two distinct sets of data-wrangling steps. The first set of steps would get you a table that counts the number of times that a given song appears on the Top 100 in a given year. The second set of steps operate on the result of the first set of steps; it would count the number of unique songs that appeared on the Top 100 in each year, irrespective of how many times it had appeared.

# %%
musical_diversity = df.groupby('year')['song_id'].nunique()
# musical_diversity.rename(columns={'song_id': 'count'},inplace = True)
musical_diversity = musical_diversity[~musical_diversity.index.isin([1958,2021])]

plt.plot(musical_diversity,  marker='o', linestyle='-') #, x= musical_diversity.index, height = musical_diversity.values)
plt.xlabel('Year')
plt.ylabel('Number of Unique Songs')
plt.title('Musical Diversity of Billboard in Top 100 (1959-2020)')
plt.show()

# %% [markdown]
# Part C: Let's define a "ten-week hit" as a single song that appeared on the Billboard Top 100 for at least ten weeks. There are 19 artists in U.S. musical history since 1958 who have had at least 30 songs that were "ten-week hits." Make a bar plot for these 19 artists, showing how many ten-week hits each one had in their musical career. Give the plot an informative caption in which you explain what is shown.

# %%
ten_week_hit = song_popularity[song_popularity['count']>=10]

ten_week_hit = ten_week_hit.groupby('performer')['song'].nunique()
artists_ten_week_hit = ten_week_hit[ten_week_hit.values >=30].sort_values(ascending = False)

plt.figure(figsize=(10, 6))
plt.bar(artists_ten_week_hit.index,artists_ten_week_hit) #, x= musical_diversity.index, height = musical_diversity.values)
plt.xlabel('Artist')
plt.ylabel('Number of ten-week Hits')
plt.title('Artists with at least 30 songs that were "ten-week hits')
plt.xticks(artists_ten_week_hit.index, rotation = '90')
plt.show()
